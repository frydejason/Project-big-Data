# %%
import pandas as pd

# %% [markdown]
# Datensatz einlesen

# %%
# Pfad zur CSV-Datei (angepasst)
PATH = r"C:\Users\zenam\OneDrive\Documents\Kurs_predictive_analytics\data_customers_shopping.csv"

# Daten aus der CSV-Datei lesen
raw_data = pd.read_csv(PATH, sep=',', encoding='utf-8', header=0)

# Eine Kopie der Rohdaten erstellen (falls benötigt)
raw_data_copy = raw_data.copy()

# %%
#um die ersten fünf Zeilen anzuzeigen
raw_data.head()
# Out:
#    CustomerID  Age Gender ItemPurchased  Category  PurchaseAmountUSD  \
# 0         1.0   55   Male        Blouse  Clothing               53.0
# 1         2.0   19   Male       Sweater  Clothing               64.0
# 2         6.0   46   Male      Sneakers  Footwear               20.0
# 3         7.0   63   Male         Shirt  Clothing               85.0
# 4         8.0   27   Male        Shorts  Clothing               34.0
#
#     Location Size     Color  Season  ReviewRating SubscriptionStatus  \
# 0   Kentucky    L      Gray  Winter           3.1                Yes
# 1      Maine    L    Maroon  Winter           3.1                Yes
# 2    Wyoming    M     White  Summer           2.9                Yes
# 3    Montana    M      Gray    Fall           3.2                Yes
# 4  Louisiana    L  Charcoal  Winter           3.2                Yes
#
#     ShippingType DiscountApplied PromoCodeUsed  PreviousPurchases  \
# ...

# %%
#um die letzten fünf Zeilen anzuzeigen
raw_data.tail()
# Out:
#       CustomerID  Age  Gender ItemPurchased     Category  PurchaseAmountUSD  \
# 1281      3881.0   42  Female         Shirt     Clothing               20.0
# 1282      3882.0   56  Female         Scarf  Accessories               25.0
# 1283      3888.0   40  Female         Shirt     Clothing               34.0
# 1284      3892.0   36  Female         Dress     Clothing               30.0
# 1285      3895.0   66  Female         Skirt     Clothing               78.0
#
#            Location Size     Color  Season  ReviewRating SubscriptionStatus  \
# 1281  Massachusetts    M       Red  Winter           3.9                 No
# 1282        Georgia    L    Silver  Spring           2.8                 No
# 1283         Kansas    M  Charcoal  Spring           2.7                 No
# 1284       Colorado    L     Peach  Winter           4.7                 No
# 1285    Connecticut    L     White  Spring           3.9                 No
#
# ...

# %%
#erlaubt uns die Dimension der Tabelle zu wissen, beziehungsweise die Anzahl von Zeile und Spalten
raw_data.shape
# Out:
# (1286, 18)

# %% [markdown]
# Wir haben 1286 Kunden in Zeile und 18 Variablen in Spalten

# %%
Um alle information über die Datensatz anzuzeigen
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1286 entries, 0 to 1285
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            1281 non-null   float64
#  1   Age                   1286 non-null   int64
#  2   Gender                1286 non-null   object
#  3   ItemPurchased         1286 non-null   object
#  4   Category              1286 non-null   object
#  5   PurchaseAmountUSD     1281 non-null   float64
#  6   Location              1279 non-null   object
#  7   Size                  1286 non-null   object
#  8   Color                 1286 non-null   object
#  9   Season                1286 non-null   object
#  10  ReviewRating          1286 non-null   float64
#  11  SubscriptionStatus    1286 non-null   object
#  12  ShippingType          1286 non-null   object
#  13  DiscountApplied       1286 non-null   object
#  14  PromoCodeUsed         1286 non-null   object
# ...

# %% [markdown]
# float: eine reelle Zahl, die sowohl positive als auch negative Werte nimmt
# object: Zeichenkette
# int: ganze Zahl

# %% [markdown]
# Überprüfung auf fehlende Werte

# %%
# um die Anzahl der Fehlwerte pro Spalte anzuzeigen
raw_data.isnull()
# Out:
#       CustomerID    Age  Gender  ItemPurchased  Category  PurchaseAmountUSD  \
# 0          False  False   False          False     False              False
# 1          False  False   False          False     False              False
# 2          False  False   False          False     False              False
# 3          False  False   False          False     False              False
# 4          False  False   False          False     False              False
# ...          ...    ...     ...            ...       ...                ...
# 1281       False  False   False          False     False              False
# 1282       False  False   False          False     False              False
# 1283       False  False   False          False     False              False
# 1284       False  False   False          False     False              False
# 1285       False  False   False          False     False              False
#
# ...

# %% [markdown]
# Bereinigung der fehlende Werte:
# Zuerst die Spalten von Daten anzeigen

# %%
#um die verfugbaren Spalten-Variablen in der Datensatz anzuzeigen
raw_data.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'ItemPurchased', 'Category',
#        'PurchaseAmountUSD', 'Location', 'Size', 'Color', 'Season',
#        'ReviewRating', 'SubscriptionStatus', 'ShippingType', 'DiscountApplied',
#        'PromoCodeUsed', 'PreviousPurchases', 'PaymentMethod',
#        'FrequencyofPurchases'],
#       dtype='object')

# %% [markdown]
# hier sind alle in der Datensatzt verfügbaren Variablen

# %%
#Um die Fehlwert anzuzeigen 
#man kann auch isna benutzen, um die Fehlwerte der Variablen anzuzeigen
raw_data.isnull().sum()
# Out:
# CustomerID              5
# Age                     0
# Gender                  0
# ItemPurchased           0
# Category                0
# PurchaseAmountUSD       5
# Location                7
# Size                    0
# Color                   0
# Season                  0
# ReviewRating            0
# SubscriptionStatus      0
# ShippingType            0
# DiscountApplied         0
# PromoCodeUsed           0
# PreviousPurchases       0
# PaymentMethod           0
# FrequencyofPurchases    0
# dtype: int64

# %% [markdown]
# Man kann feststellen, dass es Fehlewerten in drei Variablen gibt. Um zwar CustomerID, PurchaseAmountUSD, Location

# %%
# um die Modalitäten der Variablen "Location" anzuzeigen
raw_data["Location"].unique()
# Out:
# array(['Kentucky', 'Maine', 'Wyoming', 'Montana', 'Louisiana', 'Missouri',
#        'Hawaii', 'Delaware', 'New Hampshire', 'New York', 'Rhode Island',
#        'Mississippi', 'North Carolina', 'Oklahoma', 'Texas', 'Arizona',
#        'Maryland', 'Vermont', 'Alaska', 'New Mexico', 'South Carolina',
#        'West Virginia', 'New Jersey', 'Virginia', 'Indiana', 'Utah',
#        'California', 'Alabama', 'Florida', 'South Dakota', 'Washington',
#        'Kansas', 'Colorado', 'Connecticut', 'North Dakota', 'Idaho',
#        'Nebraska', 'Pennsylvania', 'Wisconsin', 'Minnesota', 'Nevada',
#        'Arkansas', 'Tennessee', 'Iowa', 'Oregon', 'Georgia',
#        'Massachusetts', 'Michigan', 'Illinois', nan, 'Ohio'], dtype=object)

# %%
#um die Anzahl der Individuen in jeder Modalität der Variablen "Location" zu wissen
raw_data["Location"].value_counts()
# Out:
# Location
# Alabama           34
# Delaware          34
# Nevada            32
# Wisconsin         32
# Illinois          31
# Louisiana         31
# New Mexico        28
# Washington        28
# West Virginia     28
# Pennsylvania      28
# Idaho             28
# New York          28
# Hawaii            28
# Oregon            28
# Wyoming           28
# Vermont           27
# Nebraska          27
# Texas             27
# Tennessee         27
# Iowa              27
# Maine             27
# Mississippi       27
# New Hampshire     27
# North Carolina    27
# North Dakota      26
# Kentucky          26
# Maryland          26
# Rhode Island      26
# Connecticut       26
# Utah              25
# Missouri          25
# Oklahoma          25
# Virginia          25
# Ohio              24
# Minnesota         24
# Colorado          24
# Montana           24
# Arkansas          23
# South Dakota      23
# South Carolina    23
# Indiana           22
# Florida           22
# Alaska            22
# ...

# %%
#um die Methode Counter zu importieren
from collections import Counter
Cm= Counter(raw_data["Location"])
max_Location= max(Cm, key=Cm.get)
max_Location
# Out:
# 'Delaware'

# %% [markdown]
# Delaware ist die Wert, die am haugfisten kommt

# %%
from collections import Counter

# Berechnung des häufigsten Werts der Variablen
häufigste_Wert = raw_data['Location'].mode()[0]

# Ersetzen des fehlenden Werts der Variablen durch den häufigsten Wert
raw_data['Location'].fillna(häufigste_Wert, inplace=True)

# Anzeigen der aktualisierten Daten
raw_data.describe()
# Out:
#         CustomerID          Age  PurchaseAmountUSD  ReviewRating  \
# count  1281.000000  1286.000000        1286.000000   1286.000000
# mean   1938.954723    43.768274          53.508977      3.677838
# std    1114.190687    16.972189          70.808055      0.866326
# min       1.000000   -65.000000        -993.000000     -3.000000
# 25%    1005.000000    31.000000          37.000000      3.100000
# 50%    1912.000000    45.000000          59.000000      3.700000
# 75%    2880.000000    57.000000          79.000000      4.300000
# max    3895.000000    70.000000         100.000000      5.000000
#
#        PreviousPurchases
# count        1286.000000
# mean           25.015552
# std            14.472991
# min             1.000000
# 25%            13.000000
# 50%            25.000000
# 75%            38.000000
# max            50.000000

# %%
raw_data.isnull().sum()
# Out:
# CustomerID              5
# Age                     0
# Gender                  0
# ItemPurchased           0
# Category                0
# PurchaseAmountUSD       0
# Location                0
# Size                    0
# Color                   0
# Season                  0
# ReviewRating            0
# SubscriptionStatus      0
# ShippingType            0
# DiscountApplied         0
# PromoCodeUsed           0
# PreviousPurchases       0
# PaymentMethod           0
# FrequencyofPurchases    0
# dtype: int64

# %%
#Um die fehleden Werte in Spalten zu löschen
raw_data.delete_column = raw_data.dropna(axis=1)
# Out:
# C:\Users\zenam\AppData\Local\Temp\ipykernel_26496\2891696648.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   raw_data.delete_column = raw_data.dropna(axis=1)

# %%
raw_data.delete_column.describe()
# Out:
#                Age  ReviewRating  PreviousPurchases
# count  1286.000000   1286.000000        1286.000000
# mean     43.768274      3.677838          25.015552
# std      16.972189      0.866326          14.472991
# min     -65.000000     -3.000000           1.000000
# 25%      31.000000      3.100000          13.000000
# 50%      45.000000      3.700000          25.000000
# 75%      57.000000      4.300000          38.000000
# max      70.000000      5.000000          50.000000

# %%
#Um die fehleden Werte zu löschen
raw_data.delete_missing = raw_data.dropna(axis=0)
#um anzuzeigen, dass die fehlende Werte in Zeilen gelöscht sind
raw_data.delete_missing.describe()
# Out:
# C:\Users\zenam\AppData\Local\Temp\ipykernel_26496\221194909.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   raw_data.delete_missing = raw_data.dropna(axis=0)
#         CustomerID          Age  PurchaseAmountUSD  ReviewRating  \
# count  1269.000000  1269.000000        1269.000000   1269.000000
# mean   1940.995272    43.810087          53.684003      3.676832
# std    1115.778960    17.009768          70.955957      0.868398
# min       1.000000   -65.000000        -993.000000     -3.000000
# 25%    1005.000000    31.000000          37.000000      3.100000
# 50%    1921.000000    45.000000          59.000000      3.700000
# 75%    2897.000000    57.000000          79.000000      4.300000
# max    3895.000000    70.000000         100.000000      5.000000
#
#        PreviousPurchases
# count        1269.000000
# mean           25.032309
# ...

# %% [markdown]
# man kann bemerken, dass alle fehlende Werte gelöscht sind und die Anzahl der Kunden in alle Variablen gleich sind

# %%
# Berechnung des Mittelwerts der Variablen "PurchaseAmountUSD"
moyenne_purchase = raw_data["PurchaseAmountUSD"].mean()
moyenne_purchase
# Out:
# 53.50897736143638

# %% [markdown]
# die PurchaseAmountUSD beträgt im Durchschnitt 53.50897736143638

# %%
# Ersetzen des fehlenden Werts der Variablen "PurchaseAmountUSD" durch den Mittelwert
raw_data["PurchaseAmountUSD"].fillna(moyenne_purchase, inplace=True)

# Anzeigen der aktualisierten Daten
raw_data.describe()
# Out:
#         CustomerID          Age  PurchaseAmountUSD  ReviewRating  \
# count  1281.000000  1286.000000        1286.000000   1286.000000
# mean   1938.954723    43.768274          53.508977      3.677838
# std    1114.190687    16.972189          70.808055      0.866326
# min       1.000000   -65.000000        -993.000000     -3.000000
# 25%    1005.000000    31.000000          37.000000      3.100000
# 50%    1912.000000    45.000000          59.000000      3.700000
# 75%    2880.000000    57.000000          79.000000      4.300000
# max    3895.000000    70.000000         100.000000      5.000000
#
#        PreviousPurchases
# count        1286.000000
# mean           25.015552
# std            14.472991
# min             1.000000
# 25%            13.000000
# 50%            25.000000
# 75%            38.000000
# max            50.000000

# %% [markdown]
# man kann hier bemerken, dass die fehlenden Werte der Variablen ersetzt wurden

# %%
raw_data.isnull().sum()
# Out:
# CustomerID              5
# Age                     0
# Gender                  0
# ItemPurchased           0
# Category                0
# PurchaseAmountUSD       0
# Location                7
# Size                    0
# Color                   0
# Season                  0
# ReviewRating            0
# SubscriptionStatus      0
# ShippingType            0
# DiscountApplied         0
# PromoCodeUsed           0
# PreviousPurchases       0
# PaymentMethod           0
# FrequencyofPurchases    0
# dtype: int64

# %%
#Zeilen aus dem DataFrame raw_data zu entfernen, bei denen die Spalte "CustomerID" fehlende Werte enthält
raw_data_cleaned = raw_data.dropna(subset=['CustomerID'])

# %%
#fehlende Werte in der Spalte "CustomerID" durch den Wert "Unknown" zu ersetzen.
raw_data['CustomerID'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\zenam\AppData\Local\Temp\ipykernel_26496\2490494244.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   raw_data['CustomerID'].fillna('Unknown', inplace=True)

# %%
raw_data.isnull().sum()
# Out:
# CustomerID              0
# Age                     0
# Gender                  0
# ItemPurchased           0
# Category                0
# PurchaseAmountUSD       0
# Location                0
# Size                    0
# Color                   0
# Season                  0
# ReviewRating            0
# SubscriptionStatus      0
# ShippingType            0
# DiscountApplied         0
# PromoCodeUsed           0
# PreviousPurchases       0
# PaymentMethod           0
# FrequencyofPurchases    0
# dtype: int64

# %% [markdown]
# Aufgabe 2

# %%
#erlaubt uns die statistische Deskriptive(nur die quantitative Variablen) anzuzeigen
raw_data.describe()
# Out:
#         CustomerID          Age  PurchaseAmountUSD  ReviewRating  \
# count  1281.000000  1286.000000        1281.000000   1286.000000
# mean   1938.954723    43.768274          53.508977      3.677838
# std    1114.190687    16.972189          70.946217      0.866326
# min       1.000000   -65.000000        -993.000000     -3.000000
# 25%    1005.000000    31.000000          37.000000      3.100000
# 50%    1912.000000    45.000000          59.000000      3.700000
# 75%    2880.000000    57.000000          79.000000      4.300000
# max    3895.000000    70.000000         100.000000      5.000000
#
#        PreviousPurchases
# count        1286.000000
# mean           25.015552
# std            14.472991
# min             1.000000
# 25%            13.000000
# 50%            25.000000
# 75%            38.000000
# max            50.000000

# %%
#erlaubt uns die statistische Deskriptive(sowohl die qualitative als auch die quantitative Variablen) anzuzeigen
raw_data.describe(include = "all")
# Out:
#          CustomerID          Age Gender ItemPurchased  Category  \
# count   1281.000000  1286.000000   1286          1286      1286
# unique          NaN          NaN      2            25         4
# top             NaN          NaN   Male         Pants  Clothing
# freq            NaN          NaN    890            62       591
# mean    1938.954723    43.768274    NaN           NaN       NaN
# std     1114.190687    16.972189    NaN           NaN       NaN
# min        1.000000   -65.000000    NaN           NaN       NaN
# 25%     1005.000000    31.000000    NaN           NaN       NaN
# 50%     1912.000000    45.000000    NaN           NaN       NaN
# 75%     2880.000000    57.000000    NaN           NaN       NaN
# max     3895.000000    70.000000    NaN           NaN       NaN
#
#         PurchaseAmountUSD Location  Size Color  Season  ReviewRating  \
# count         1281.000000     1279  1286  1286    1286   1286.000000
# ...

# %% [markdown]
# NaN bedeutet, dass die Statistik ist für die qualitative Variable nicht relevant

# %%
#um eine grafische Darstellung von der Variable "PurchaseAmountUSD" zu haben
raw_data["PurchaseAmountUSD"].value_counts().plot(kind= "bar")
# Out:
# <Axes: xlabel='PurchaseAmountUSD'>
